# %% [markdown]
# # Práctica 6
#
# Apache Spark: Dataframes y SQL en juegos Olimpicos

# %% [markdown]
# ## 1. Carga de datos
#
# 1. Instalación de Spark, DataFrames y SQL
# 2. Carga de archivos: deportistas, países, eventos, juegos y resultados
# 3. Preprocesamiento de datos

# %%
#Instalar Java: Spark requiere Java, así que primero debo instalar OpenJDK 8 en el entorno de Colab.
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %%
#Descargar y extraer Apache Spark: eso se hace con con Hadoop 2.7 y extrae el archivo
# !wget -q https://www-us.apache.org/dist/spark/spark-3.1.2/spark-3.1.2-bin-hadoop2.7.tgz

# %%
# !tar xf spark-3.1.2-bin-hadoop2.7.tgz
# Out:
# tar: spark-3.1.2-bin-hadoop2.7.tgz: Cannot open: No such file or directory
# tar: Error is not recoverable: exiting now
