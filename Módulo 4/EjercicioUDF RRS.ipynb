# %% [markdown]
# Instalar el entorno

# %%
# !apt-get update
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://downloads.apache.org/spark/spark-3.5.1/spark-3.5.1-bin-hadoop3.tgz
# !tar xvf spark-3.5.1-bin-hadoop3.tgz

# %%
# !pip install -q findspark

# %%
# !ls /usr/lib/jvm/
# Out:
# java-1.11.0-openjdk-amd64  java-11-openjdk-amd64  java-1.8.0-openjdk-amd64  java-8-openjdk-amd64

# %%
# !ls /usr/lib/jvm/java-8-openjdk-amd64/
# Out:
# ASSEMBLY_EXCEPTION  bin  docs  include	jre  lib  man  src.zip	THIRD_PARTY_README

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.5.1-bin-hadoop3"
# !update-alternatives --set java /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java
# !java -version
# Out:
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java to provide /usr/bin/java (java) in manual mode
# openjdk version "1.8.0_402"
# OpenJDK Runtime Environment (build 1.8.0_402-8u402-ga-2ubuntu1~22.04-b06)
# OpenJDK 64-Bit Server VM (build 25.402-b06, mixed mode)

# %%
import findspark
findspark.init()

# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, FloatType
from pyspark.sql.types import Row
from pyspark.sql import SQLContext

# %%
from pyspark import SparkContext
sc = SparkContext(master="local", appName="UDF")

# %%
path = "/content/drive/MyDrive/+Diplomado CyAD/Módulo 4/DiplomadoBigData/Datasets/ParaUsarEnSpark/"
deportistaError = sc.textFile(path+"deportistaError.csv").map(lambda line: line.split(","))

# %%
deportistaError = sc.textFile(path+"deportistaError.csv").map(lambda line: line.split(","))

# %%
deportistaError(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-38ef34eec650> in <cell line: 1>()
# ----> 1 deportistaError(5)
#
# TypeError: 'PipelinedRDD' object is not callable

# %%
# Convert the deportistaError RDD into a list
deportistaError_list = deportistaError.collect()

# Access the fifth element of the list
fifth_element = deportistaError_list[5]

# Print the fifth element
print(fifth_element)
# Out:
# ['5', 'Christine Jacoba Aaftink', '2', '21', '185', '82', '705']

# %%
#funcion para eliminar los encabezados, RDD
def eliminaEncabezado(index,iterator)
return iter(list(iterator)[1])
# Out:
#   File "<ipython-input-22-81c360549514>", line 2
#     def eliminaEncabezado(index,iterator)
#                                          ^
# SyntaxError: expected ':'
